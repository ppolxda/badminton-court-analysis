# %% [markdown]
# # 羽毛球3D轨迹可视化（示例与说明）
# 本Notebook演示如何加载数据、绘制标准3D羽毛球场地、可视化多条轨迹，并播放动画。

# %%
# !pip -q install plotly pandas numpy 'nbformat>=4.2.0'

# %% [markdown]
# ## 1. 导入与依赖

# %%
from pathlib import Path
import json
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import sys
# sys.path.append(str(Path('.').resolve()))
# sys.path.append('./')
from badminton_vis import (
    CourtSpec, load_from_json_file, load_from_json_obj, load_from_dataframe,
    sort_and_clean, smooth, interpolate_time, make_figure, make_animation,
    save_html, make_parabola_example
)

# %% [markdown]
# ## 2. 数据格式与示例
# 示例JSON位于 `/mnt/data/badminton_3d_vis/sample_trajectory.json`，符合规格中的字段定义。

# %%
sample_path = './sample_trajectory.json'
with open(sample_path, 'r', encoding='utf-8') as f:
    sample_obj = json.load(f)
sample_obj
# Out:
# {'msgtype': 'pred_track',
#  'pid': 'sample1',
#  'positions': [{'frame_id': 0,
#    'ts': 0.0,
#    'pos': {'x': -3.0, 'y': 0.0, 'z': 0.05}},
#   {'frame_id': 1,
#    'ts': 10.0,
#    'pos': {'x': -2.9240506329113924,
#     'y': 0.06356013357737149,
#     'z': 0.24995994231693686}},
#   {'frame_id': 2,
#    'ts': 20.0,
#    'pos': {'x': -2.848101265822785,
#     'y': 0.12671841952577198,
#     'z': 0.4935106553436952}},
#   {'frame_id': 3,
#    'ts': 30.0,
#    'pos': {'x': -2.7721518987341773,
#     'y': 0.1890755508263239,
#     'z': 0.730652139080275}},
#   {'frame_id': 4,
#    'ts': 40.0,
#    'pos': {'x': -2.6962025316455698,
#     'y': 0.2502372856177817,
#     'z': 0.961384393526678}},
#   {'frame_id': 5,
#    'ts': 50.0,
#    'pos': {'x': -2.620253164556962,
#     'y': 0.30981693972051283,
#     'z': 1.1857074186829037}},
#   {'frame_id': 6,
#    'ts': 60.0,
#    'pos': {'x': -2.5443037974683547,
#     'y': 0.3674378313783824,
#     'z': 1.4036212145489508}},
#   {'frame_id': 7,
#    'ts': 70.0,
#    'pos': {'x': -2.4683544303797467,
#     'y': 0.42273566276209557,
#     'z': 1.6151257811248203}},
#   {'frame_id': 8,
#    'ts': 80.0,
#    'pos': {'x': -2.392405063291139,
#     'y': 0.4753608231773684,
#     'z': 1.820221118410511}},
#   {'frame_id': 9,
#    'ts': 90.0,
#    'pos': {'x': -2.3164556962025316,
#     'y': 0.5249805994163005,
#     'z': 2.018907226406025}},
#   {'frame_id': 10,
#    'ts': 100.0,
#    'pos': {'x': -2.240506329113924,
#     'y': 0.5712812792773998,
#     'z': 2.2111841051113608}},
#   {'frame_id': 11,
#    'ts': 110.0,
#    'pos': {'x': -2.1645569620253164,
#     'y': 0.6139701349551263,
#     'z': 2.3970517545265175}},
#   {'frame_id': 12,
#    'ts': 120.0,
#    'pos': {'x': -2.088607594936709,
#     'y': 0.6527772737593288,
#     'z': 2.5765101746514985}},
#   {'frame_id': 13,
#    'ts': 130.0,
#    'pos': {'x': -2.0126582278481013,
#     'y': 0.6874573444637289,
#     'z': 2.7495593654863004}},
#   {'frame_id': 14,
#    'ts': 140.0,
#    'pos': {'x': -1.9367088607594938,
#     'y': 0.7177910884953698,
#     'z': 2.9161993270309243}},
#   {'frame_id': 15,
#    'ts': 150.0,
#    'pos': {'x': -1.860759493670886,
#     'y': 0.7435867261579097,
#     'z': 3.076430059285371}},
#   {'frame_id': 16,
#    'ts': 160.0,
#    'pos': {'x': -1.7848101265822784,
#     'y': 0.7646811691246086,
#     'z': 3.2302515622496393}},
#   {'frame_id': 17,
#    'ts': 170.0,
#    'pos': {'x': -1.7088607594936709,
#     'y': 0.7809410515352407,
#     'z': 3.377663835923731}},
#   {'frame_id': 18,
#    'ts': 180.0,
#    'pos': {'x': -1.6329113924050633,
#     'y': 0.7922635731780016,
#     'z': 3.5186668803076424}},
#   {'frame_id': 19,
#    'ts': 190.0,
#    'pos': {'x': -1.5569620253164556,
#     'y': 0.7985771494255465,
#     'z': 3.6532606954013778}},
#   {'frame_id': 20,
#    'ts': 200.0,
#    'pos': {'x': -1.481012658227848,
#     'y': 0.7998418638160525,
#     'z': 3.7814452812049355}},
#   {'frame_id': 21,
#    'ts': 210.0,
#    'pos': {'x': -1.4050632911392407,
#     'y': 0.7960497204179421,
#     'z': 3.9032206377183143}},
#   {'frame_id': 22,
#    'ts': 220.0,
#    'pos': {'x': -1.3291139240506329,
#     'y': 0.7872246943827366,
#     'z': 4.0185867649415155}},
#   {'frame_id': 23,
#    'ts': 230.0,
#    'pos': {'x': -1.2531645569620253,
#     'y': 0.7734225803664297,
#     'z': 4.127543662874539}},
#   {'frame_id': 24,
#    'ts': 240.0,
#    'pos': {'x': -1.1772151898734178,
#     'y': 0.7547306397777077,
#     'z': 4.230091331517385}},
#   {'frame_id': 25,
#    'ts': 250.0,
#    'pos': {'x': -1.10126582278481,
#     'y': 0.7312670490832277,
#     'z': 4.326229770870053}},
#   {'frame_id': 26,
#    'ts': 260.0,
#    'pos': {'x': -1.0253164556962027,
#     'y': 0.7031801526579471,
#     'z': 4.415958980932543}},
#   {'frame_id': 27,
#    'ts': 270.0,
#    'pos': {'x': -0.9493670886075951,
#     'y': 0.6706475249042214,
#     'z': 4.499278961704855}},
#   {'frame_id': 28,
#    'ts': 280.0,
#    'pos': {'x': -0.8734177215189876,
#     'y': 0.6338748475692595,
#     'z': 4.57618971318699}},
#   {'frame_id': 29,
#    'ts': 290.0,
#    'pos': {'x': -0.7974683544303796,
#     'y': 0.5930946093588945,
#     'z': 4.646691235378945}},
#   {'frame_id': 30,
#    'ts': 300.0,
#    'pos': {'x': -0.721518987341772,
#     'y': 0.5485646360691305,
#     'z': 4.710783528280724}},
#   {'frame_id': 31,
#    'ts': 310.0,
#    'pos': {'x': -0.6455696202531644,
#     'y': 0.5005664605284481,
#     'z': 4.768466591892325}},
#   {'frame_id': 32,
#    'ts': 320.0,
#    'pos': {'x': -0.5696202531645569,
#     'y': 0.44940354265661697,
#     'z': 4.819740426213748}},
#   {'frame_id': 33,
#    'ts': 330.0,
#    'pos': {'x': -0.49367088607594933,
#     'y': 0.3953993508933784,
#     'z': 4.864605031244993}},
#   {'frame_id': 34,
#    'ts': 340.0,
#    'pos': {'x': -0.4177215189873418,
#     'y': 0.3388953171268223,
#     'z': 4.90306040698606}},
#   {'frame_id': 35,
#    'ts': 350.0,
#    'pos': {'x': -0.3417721518987342,
#     'y': 0.28024867805105974,
#     'z': 4.935106553436949}},
#   {'frame_id': 36,
#    'ts': 360.0,
#    'pos': {'x': -0.26582278481012667,
#     'y': 0.21983021660082042,
#     'z': 4.96074347059766}},
#   {'frame_id': 37,
#    'ts': 370.0,
#    'pos': {'x': -0.1898734177215191,
#     'y': 0.1580219177423624,
#     'z': 4.979971158468194}},
#   {'frame_id': 38,
#    'ts': 380.0,
#    'pos': {'x': -0.11392405063291111,
#     'y': 0.0952145534415239,
#     'z': 4.992789617048549}},
#   {'frame_id': 39,
#    'ts': 390.0,
#    'pos': {'x': -0.037974683544303556,
#     'y': 0.031805212077540355,
#     'z': 4.999198846338728}},
#   {'frame_id': 40,
#    'ts': 400.0,
#    'pos': {'x': 0.037974683544304,
#     'y': -0.031805212077540515,
#     'z': 4.999198846338728}},
#   {'frame_id': 41,
#    'ts': 410.0,
#    'pos': {'x': 0.11392405063291111,
#     'y': -0.09521455344152369,
#     'z': 4.992789617048549}},
#   {'frame_id': 42,
#    'ts': 420.0,
#    'pos': {'x': 0.18987341772151867,
#     'y': -0.15802191774236188,
#     'z': 4.979971158468194}},
#   {'frame_id': 43,
#    'ts': 430.0,
#    'pos': {'x': 0.26582278481012667,
#     'y': -0.2198302166008202,
#     'z': 4.96074347059766}},
#   {'frame_id': 44,
#    'ts': 440.0,
#    'pos': {'x': 0.3417721518987342,
#     'y': -0.28024867805105924,
#     'z': 4.935106553436949}},
#   {'frame_id': 45,
#    'ts': 450.0,
#    'pos': {'x': 0.4177215189873422,
#     'y': -0.3388953171268225,
#     'z': 4.90306040698606}},
#   {'frame_id': 46,
#    'ts': 460.0,
#    'pos': {'x': 0.49367088607594933,
#     'y': -0.3953993508933782,
#     'z': 4.864605031244993}},
#   {'frame_id': 47,
#    'ts': 470.0,
#    'pos': {'x': 0.5696202531645564,
#     'y': -0.44940354265661653,
#     'z': 4.819740426213748}},
#   {'frame_id': 48,
#    'ts': 480.0,
#    'pos': {'x': 0.6455696202531644,
#     'y': -0.5005664605284479,
#     'z': 4.768466591892325}},
#   {'frame_id': 49,
#    'ts': 490.0,
#    'pos': {'x': 0.721518987341772,
#     'y': -0.5485646360691304,
#     'z': 4.710783528280724}},
#   {'frame_id': 50,
#    'ts': 500.0,
#    'pos': {'x': 0.79746835443038,
#     'y': -0.5930946093588946,
#     'z': 4.646691235378945}},
#   {'frame_id': 51,
#    'ts': 510.0,
#    'pos': {'x': 0.8734177215189876,
#     'y': -0.6338748475692593,
#     'z': 4.57618971318699}},
#   {'frame_id': 52,
#    'ts': 520.0,
#    'pos': {'x': 0.9493670886075947,
#     'y': -0.6706475249042212,
#     'z': 4.499278961704855}},
#   {'frame_id': 53,
#    'ts': 530.0,
#    'pos': {'x': 1.0253164556962027,
#     'y': -0.703180152657947,
#     'z': 4.415958980932543}},
#   {'frame_id': 54,
#    'ts': 540.0,
#    'pos': {'x': 1.1012658227848098,
#     'y': -0.7312670490832276,
#     'z': 4.326229770870053}},
#   {'frame_id': 55,
#    'ts': 550.0,
#    'pos': {'x': 1.1772151898734178,
#     'y': -0.7547306397777078,
#     'z': 4.230091331517385}},
#   {'frame_id': 56,
#    'ts': 560.0,
#    'pos': {'x': 1.253164556962025,
#     'y': -0.7734225803664296,
#     'z': 4.127543662874539}},
#   {'frame_id': 57,
#    'ts': 570.0,
#    'pos': {'x': 1.3291139240506329,
#     'y': -0.7872246943827365,
#     'z': 4.018586764941516}},
#   {'frame_id': 58,
#    'ts': 580.0,
#    'pos': {'x': 1.4050632911392409,
#     'y': -0.7960497204179421,
#     'z': 3.9032206377183143}},
#   {'frame_id': 59,
#    'ts': 590.0,
#    'pos': {'x': 1.481012658227848,
#     'y': -0.7998418638160525,
#     'z': 3.7814452812049355}},
#   {'frame_id': 60,
#    'ts': 600.0,
#    'pos': {'x': 1.556962025316456,
#     'y': -0.7985771494255465,
#     'z': 3.6532606954013773}},
#   {'frame_id': 61,
#    'ts': 610.0,
#    'pos': {'x': 1.6329113924050631,
#     'y': -0.7922635731780016,
#     'z': 3.5186668803076424}},
#   {'frame_id': 62,
#    'ts': 620.0,
#    'pos': {'x': 1.708860759493671,
#     'y': -0.7809410515352408,
#     'z': 3.377663835923731}},
#   {'frame_id': 63,
#    'ts': 630.0,
#    'pos': {'x': 1.784810126582279,
#     'y': -0.7646811691246087,
#     'z': 3.2302515622496393}},
#   {'frame_id': 64,
#    'ts': 640.0,
#    'pos': {'x': 1.8607594936708862,
#     'y': -0.7435867261579099,
#     'z': 3.076430059285371}},
#   {'frame_id': 65,
#    'ts': 650.0,
#    'pos': {'x': 1.9367088607594942,
#     'y': -0.7177910884953698,
#     'z': 2.916199327030924}},
#   {'frame_id': 66,
#    'ts': 660.0,
#    'pos': {'x': 2.0126582278481013,
#     'y': -0.6874573444637289,
#     'z': 2.7495593654863004}},
#   {'frame_id': 67,
#    'ts': 670.0,
#    'pos': {'x': 2.0886075949367084,
#     'y': -0.6527772737593293,
#     'z': 2.5765101746514985}},
#   {'frame_id': 68,
#    'ts': 680.0,
#    'pos': {'x': 2.1645569620253164,
#     'y': -0.6139701349551262,
#     'z': 2.3970517545265175}},
#   {'frame_id': 69,
#    'ts': 690.0,
#    'pos': {'x': 2.2405063291139236,
#     'y': -0.5712812792773999,
#     'z': 2.2111841051113608}},
#   {'frame_id': 70,
#    'ts': 700.0,
#    'pos': {'x': 2.3164556962025316,
#     'y': -0.524980599416301,
#     'z': 2.0189072264060255}},
#   {'frame_id': 71,
#    'ts': 710.0,
#    'pos': {'x': 2.3924050632911396,
#     'y': -0.4753608231773682,
#     'z': 1.820221118410511}},
#   {'frame_id': 72,
#    'ts': 720.0,
#    'pos': {'x': 2.4683544303797467,
#     'y': -0.42273566276209584,
#     'z': 1.6151257811248203}},
#   {'frame_id': 73,
#    'ts': 730.0,
#    'pos': {'x': 2.5443037974683547,
#     'y': -0.3674378313783824,
#     'z': 1.4036212145489495}},
#   {'frame_id': 74,
#    'ts': 740.0,
#    'pos': {'x': 2.620253164556962,
#     'y': -0.30981693972051333,
#     'z': 1.1857074186829037}},
#   {'frame_id': 75,
#    'ts': 750.0,
#    'pos': {'x': 2.6962025316455698,
#     'y': -0.2502372856177821,
#     'z': 0.9613843935266791}},
#   {'frame_id': 76,
#    'ts': 760.0,
#    'pos': {'x': 2.7721518987341778,
#     'y': -0.18907555082632405,
#     'z': 0.730652139080275}},
#   {'frame_id': 77,
#    'ts': 770.0,
#    'pos': {'x': 2.848101265822785,
#     'y': -0.1267184195257726,
#     'z': 0.4935106553436952}},
#   {'frame_id': 78,
#    'ts': 780.0,
#    'pos': {'x': 2.924050632911393,
#     'y': -0.0635601335773712,
#     'z': 0.24995994231693575}},
#   {'frame_id': 79,
#    'ts': 790.0,
#    'pos': {'x': 3.0, 'y': -1.9594348786357652e-16, 'z': 0.05}}],
#  'timestamp': 0}

# %% [markdown]
# ## 3. 加载与解析
# 支持从JSON对象/文件或DataFrame加载，自动生成 `pid, frame_id, ts, x, y, z, vx, vy, vz` 字段。

# %%
trajs = load_from_json_file(sample_path)
df = pd.concat([t.to_dataframe() for t in trajs], ignore_index=True)
df = sort_and_clean(df)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 trajs = load_from_json_file(sample_path)
#       2 df = pd.concat([t.to_dataframe() for t in trajs], ignore_index=True)
#       3 df = sort_and_clean(df)
#
# File ~/Desktop/Project/yumaoqiu/3d_ball_show/badminton_vis.py:151, in load_from_json_file(path)
#     147         obj = json.load(f)
#     148     return load_from_json_obj(obj)
# --> 151 def load_from_dataframe(
#     152     df: pd.DataFrame,
#     153     pid_col: str = "pid",
#     154     x_col: str = "x",
#     155     y_col: str = "y",
#     156     z_col: str = "z",
#     157     ts_col: Optional[str] = "ts",
#     158     frame_id_col: Optional[str] = "frame_id",
#     159     vx_col: Optional[str] = "vx",
#     160     vy_col: Optional[str] = "vy",
#     161     vz_col: Optional[str] = "vz",
#     162 ) -> List[Trajectory]:
#     163     """
#     164     Flexible loader from a user-provided dataframe.
#     165     """
#     166     required = [pid_col, x_col, y_col, z_col]
#
# File ~/Desktop/Project/yumaoqiu/3d_ball_show/badminton_vis.py:143, in load_from_json_obj(obj)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/Project/yumaoqiu/3d_ball_show/badminton_vis.py:106, in _parse_positions(positions)
#     104 pts: List[TrajectoryPoint] = []
#     105 for item in positions:
# --> 106     pos = item.get("pos") or {}
#     107     p = TrajectoryPoint(
#     108         frame_id=item.get("frame_id"),
#     109         ts=float(item["ts"]) if "ts" in item and item["ts"] is not None else None,
#    (...)    116         raw=item,
#     117     )
#     118     pts.append(p)
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1465, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1507, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1308, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1945, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~/.pyenv/versions/anaconda3-2024.10-1/envs/aitest/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2185, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2182             from_this_thread.append(frame_custom_thread_id)
#    2184     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2185         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2187 frames_list = None
#    2189 if keep_suspended:
#    2190     # This means that we should pause again after a set next statement.
#
# File ~/.pyenv/versions/anaconda3-2024.10-1/envs/aitest/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2254, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2251                 queue.put(internal_cmd)
#    2252                 wait_timeout = TIMEOUT_FAST
# -> 2254         notify_event.wait(wait_timeout)
#    2255         notify_event.clear()
#    2257 finally:
#
# File ~/.pyenv/versions/anaconda3-2024.10-1/envs/aitest/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/.pyenv/versions/anaconda3-2024.10-1/envs/aitest/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4. 绘制静态3D场地与轨迹

# %%
court = CourtSpec()  # 可传入自定义尺寸
fig = make_figure(df, court=court, title='Badminton 3D Trajectories - Static')
fig.show()

# %% [markdown]
# ## 5. 轨迹动画（根据时间戳ts）

# %%
anim_fig = make_animation(df, court=CourtSpec(), title='Badminton 3D Trajectory Animation', time_col='ts')
anim_fig.show()

# %% [markdown]
# ## 6. 多轨迹演示与平滑/插值
# 这里创建另一条仿真轨迹并与示例轨迹一起显示，同时展示平滑与按固定时间步长插值。

# %%
# 生成另一条抛物线轨迹
demo_trajs = make_parabola_example(pid='demo2', apex=(0.0, -1.0, 6.0), span_x=7.0)
df2 = pd.concat([t.to_dataframe() for t in demo_trajs], ignore_index=True)
df_multi = pd.concat([df, df2], ignore_index=True)
df_multi = sort_and_clean(df_multi)

# 可选：平滑
df_smooth = smooth(df_multi, window=5)

# 可选：按固定时间步插值（需要ts列）
df_interp = interpolate_time(df_smooth, freq_ms=20)

fig_multi = make_figure(df_interp, court=CourtSpec(), title='Multiple Trajectories (Smoothed & Interpolated)')
fig_multi.show()

# %% [markdown]
# ## 7. 导出（HTML）

# %%
export_path = '/mnt/data/badminton_3d_vis/trajectory_visualization.html'
save_html(fig_multi, export_path)
export_path

# %% [markdown]
# ## 8. 常见问题（FAQ）
# - **坐标单位**：默认以米为单位。
# - **坐标系**：原点在场地中心地面，x为场地长度方向，y为宽度方向，z向上。
# - **自定义场地**：通过 `CourtSpec(length=..., width_doubles=..., net_height_center=...)` 调整。
# - **数据来源**：可使用 `load_from_json_file/json_obj/dataframe` 加载；DataFrame方式可映射自定义列名。
# - **动画时间**：优先使用 `ts`（毫秒）；如缺失，将按采样序号合成时间。
# - **导出**：使用 `save_html(fig, path)` 导出可交互HTML，便于分享。
